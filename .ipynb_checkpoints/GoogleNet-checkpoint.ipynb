# %%
import torch
from torch import autograd
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn as nn
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
import copy
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torchvision import datasets

# %%
in_height = 120
in_width = 120
in_channels = 3

# %%
##Divide ConvNet into multiple parts 
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return F.relu(x, inplace=True)

# %%
## conv layer (stem layer)
class _Stem(nn.Module): 
    def __init__(self):
        super(_Stem, self).__init__()
        self.stem = nn.Sequential(
                        BasicConv2d(in_channels, 64, kernel_size=7, padding=2, stride=2),
                        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                        BasicConv2d(64, 64, kernel_size=1),
                        BasicConv2d(64, 192, kernel_size=3, padding=1),
                        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                    )

    def forward(self, x):
        x = self.stem(x)

        return x

# %%
## auxiliary layer for vanishing gradient
class _Auxiliary_Classifiers(nn.Module):
    def __init__(self, num_fts):
        super(_Auxiliary_Classifiers, self).__init__()
        self.aux_classifier = nn.Sequential(
                                    nn.AvgPool2d(kernel_size=5, stride=3, padding=2),
                                    BasicConv2d(num_fts, 128, kernel_size=1),
                                )

        self.classifier = nn.Sequential(
                                nn.Linear(5 * 5 * 128, 1024),
                                nn.Dropout(p=0.7),
                                nn.Linear(1024, 5)
                            )

    def forward(self, x):
        x = self.aux_classifier(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)

        return x

# %%
class _Inception_Module(nn.Module):
    def __init__(self, conv1x1, conv1x1_reduce_3, conv1x1_reduce_5,
                        conv3x3, conv5x5, conv1x1_reduce_pool,
                        num_fts):
        super(_Inception_Module, self).__init__()

        self.conv1x1_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1, kernel_size=1),
                                )

        self.conv3x3_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1_reduce_3, kernel_size=1),
                                    BasicConv2d(conv1x1_reduce_3, conv3x3, kernel_size=3, padding=1),
                                )

        self.conv5x5_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1_reduce_5, kernel_size=1),
                                    BasicConv2d(conv1x1_reduce_5, conv5x5, kernel_size=5, padding=2),
                                )

        self.pool_branch = nn.Sequential(
                                    nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
                                    BasicConv2d(num_fts, conv1x1_reduce_pool, kernel_size=1),
                                )

    def forward(self, x):
        x1x1 = self.conv1x1_branch(x)
        x3x3 = self.conv3x3_branch(x)
        x5x5 = self.conv5x5_branch(x)
        xpool = self.pool_branch(x)

        x = torch.cat([x1x1, x3x3, x5x5, xpool], 1)

        return x

# %%
class GoogleLeNet(nn.Module):
    def __init__(self):
        super(GoogleLeNet, self).__init__()
        self.features1 = nn.Sequential(
                            _Stem(),
                            _Inception_Module(conv1x1=64, conv1x1_reduce_3=96, conv3x3=128, 
                                conv1x1_reduce_5=16, conv5x5=32, conv1x1_reduce_pool=32, 
                                num_fts=192),
                            _Inception_Module(conv1x1=128, conv1x1_reduce_3=128, conv3x3=192, 
                                conv1x1_reduce_5=32, conv5x5=96, conv1x1_reduce_pool=64, 
                                num_fts=256),
                            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                            _Inception_Module(conv1x1=192, conv1x1_reduce_3=96, conv3x3=208, 
                                conv1x1_reduce_5=16, conv5x5=48, conv1x1_reduce_pool=64, 
                                num_fts=480)
                        )

        self.features2 = nn.Sequential(
                            _Inception_Module(conv1x1=160, conv1x1_reduce_3=112, conv3x3=224, 
                                conv1x1_reduce_5=24, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512),
                            _Inception_Module(conv1x1=128, conv1x1_reduce_3=128, conv3x3=256, 
                                conv1x1_reduce_5=24, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512),
                            _Inception_Module(conv1x1=112, conv1x1_reduce_3=144, conv3x3=288, 
                                conv1x1_reduce_5=32, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512)
                        )

        self.features3 = nn.Sequential(
                            _Inception_Module(conv1x1=256, conv1x1_reduce_3=160, conv3x3=320, 
                                conv1x1_reduce_5=32, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=528),
                            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                            _Inception_Module(conv1x1=256, conv1x1_reduce_3=160, conv3x3=320, 
                                conv1x1_reduce_5=32, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=832),
                            _Inception_Module(conv1x1=384, conv1x1_reduce_3=192, conv3x3=384, 
                                conv1x1_reduce_5=48, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=832)
                        )
        
        self.Aux1 = _Auxiliary_Classifiers(num_fts=512)
        self.Aux2 = _Auxiliary_Classifiers(num_fts=528)

        self.fc = nn.Linear(1024, 5)
    def forward(self, x):
        x = self.features1(x)

        if self.training:
            aux1 = self.Aux1(x)

        x = self.features2(x)

        if self.training:
            aux2 = self.Aux2(x)

        x = self.features3(x)
        x = F.avg_pool2d(x, kernel_size=7)
        x = x.view(-1 ,1024)
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.fc(x)
        
        if self.training:
            return x, aux1, aux2
        else:
            return x

# %%
def train(model, criterion, optimizer, lr_scheduler, dsets_loader, dset_sizes, lr = 0.001, num_epochs = 20):
    since = time.time()
    use_model = model
    best_acc = 0.0
    #accuracy = []
    #epoch_num = []
    #loss_arr = []
    history = {
        x :[]
        for x in ['train','val']
    }
    
    for i in range(num_epochs):
        print('Epoch {}/{}'.format(i, num_epochs - 1))
        print('-'*10)
        for mode in ['train','val']:
            start = time.time()
            
            if mode == 'train':
                optimizer = lr_scheduler(optimizer, i, init_lr = lr)
                model.train()
            else:
                model.eval()
            
            running_loss = 0.0
            running_corrects = 0
            
            for data in dsets_loader[mode]:
                
                inputs, labels = data
                #print(inputs)
                inputs_, labels_ = Variable(inputs.cuda()), Variable(labels.cuda())
                
                optimizer.zero_grad()
                
                
                
                if mode == 'train':
                    o1, o2, o3 = model(inputs_)
                    _, preds = torch.max(o1.data, 1)
                
                    loss1 = criterion(o1, labels_)
                    loss2 = criterion(o2, labels_)
                    loss3 = criterion(o3, labels_)

                    loss = loss1 + 0.3 * (loss2 + loss3)
                   
                else:
                    outputs = model(inputs_)
                    _, preds = torch.max(outputs.data, 1)
                    loss = criterion(outputs, labels_)
                if mode == 'train':
                    loss.backward()
                    optimizer.step()
                running_loss += loss.data[0]
                running_corrects += torch.sum(preds == labels_.data)
                
            epoch_loss = running_loss / dset_sizes[mode]
            #loss_arr.append(epoch_loss)
            epoch_acc = running_corrects / dset_sizes[mode]
            #accuracy.append(epoch_acc)
            epoch_time = time.time() - start
            
            history_dict =  {
                'mode':mode,
                'epoch':i,
                'epoch_loss': epoch_loss,
                'epoch_accuracy': epoch_acc,
                'learing_rate':optimizer.state_dict()['param_groups'][0]['lr']
                
            }
            
            history[mode].append(history_dict)
            
            print('{} Loss: {:.4f} Acc:{:.4f} Time: {:.0f}m {:.0f}s'.format(mode, epoch_loss, epoch_acc, epoch_time//60, epoch_time%60))
            
            if mode == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model)
        print()
    time_elapsed = time.time() - since
    
    print('Training completion in {:.0f}m {:.0f}s'.format(time_elapsed//60, time_elapsed%60))
    print('Best validation accuracy is {:.4f}'.format(best_acc))
    
    print('save mode')
    ##here I want to save the history of the process in order to debug
    with open('history.pickle','wb') as f:
        pickle.dump(history, f)
    
    return best_model, best_acc, history

# %%
#add scheduler to better control learning rate 
def exp_lr_scheduler(optimizer, epoch, init_lr = 0.001, lr_decay_epoch = 5):
    lr = init_lr * (0.9 ** (epoch // lr_decay_epoch))
    
    if epoch % lr_decay_epoch == 0:
        print('Learning rate is changed to {}'.format(lr))
    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return optimizer

# %%
net = GoogleLeNet().cuda()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), weight_decay = 0.0005)
lr_scheduler = exp_lr_scheduler
lr = 0.001

# %%
def load_data(train_path, val_path=None):
    if val_path is None:
        val_path = train_path
    train_transfrom = transforms.Compose([
        
        transforms.Scale(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.255])
                ])

    val_transfrom = transforms.Compose([
        transforms.Scale(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.255])
                ])
    dsets = {
        'train': datasets.ImageFolder(train_path, train_transfrom),
        'val': datasets.ImageFolder(val_path, val_transfrom)
    }
    dset_loaders = {
        x: torch.utils.data.DataLoader(dsets[x], batch_size=7, shuffle=True, num_workers=4)
        for x in ['train', 'val']
    }
    dset_sizes = {
        x: len(dsets[x])
        for x in ['train', 'val']
    }
    
    dset_classes = dsets['train'].classes
    return dset_loaders, dset_sizes, dset_classes

# %%
train_file = './alzheimers'
val_file = ''
##load data
#dset_loaders, dset_sizes, dset_classes = mri_loader.load_data(train_path=train_path, val_path=val_path)

# %%
dset_loaders, dset_sizes, dset_classes = load_data(train_path=train_file)

print(dset_sizes)
print(dset_classes)
print(dset_loaders)
# Out:
# {'train': 101, 'val': 101}
# ['label_0', 'label_1', 'label_2']
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x7fa7f2d9a128>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7fa7f41f63c8>}

# %%
best_model, best_acc, history = train(net, criterion, optimizer, lr_scheduler,
dset_loaders, dset_sizes, lr, 80)
# Out:
# Epoch 0/79
# ----------
# Learning rate is changed to 0.001
# train Loss: 0.2628 Acc:0.5743 Time: 0m 1s
# val Loss: 0.2629 Acc:0.5050 Time: 0m 0s
#
# Epoch 1/79
# ----------
# train Loss: 0.1989 Acc:0.7129 Time: 0m 1s
# val Loss: 0.9717 Acc:0.5050 Time: 0m 0s
#
# Epoch 2/79
# ----------
# train Loss: 0.2104 Acc:0.5842 Time: 0m 1s
# val Loss: 0.1555 Acc:0.5050 Time: 0m 0s
#
# Epoch 3/79
# ----------
# train Loss: 0.1982 Acc:0.7129 Time: 0m 1s
# val Loss: 0.0947 Acc:0.7228 Time: 0m 0s
#
# Epoch 4/79
# ----------
# train Loss: 0.2181 Acc:0.6634 Time: 0m 1s
# val Loss: 0.1031 Acc:0.7426 Time: 0m 0s
#
# Epoch 5/79
# ----------
# Learning rate is changed to 0.0009000000000000001
# train Loss: 0.1636 Acc:0.7228 Time: 0m 1s
# val Loss: 0.2373 Acc:0.3663 Time: 0m 0s
#
# Epoch 6/79
# ----------
# train Loss: 0.1804 Acc:0.6733 Time: 0m 1s
# val Loss: 0.0904 Acc:0.7129 Time: 0m 0s
#
# Epoch 7/79
# ----------
# train Loss: 0.1567 Acc:0.7327 Time: 0m 1s
# val Loss: 0.0977 Acc:0.5842 Time: 0m 0s
#
# Epoch 8/79
# ----------
# train Loss: 0.1515 Acc:0.6931 Time: 0m 1s
# val Loss: 0.0955 Acc:0.6337 Time: 0m 0s
#
# Epoch 9/79
# ----------
# train Loss: 0.1278 Acc:0.7426 Time: 0m 1s
# val Loss: 0.0694 Acc:0.7921 Time: 0m 0s
#
# Epoch 10/79
# ----------
# Learning rate is changed to 0.0008100000000000001
# train Loss: 0.1060 Acc:0.7822 Time: 0m 1s
# val Loss: 0.1098 Acc:0.7228 Time: 0m 0s
#
# Epoch 11/79
# ----------
# train Loss: 0.1176 Acc:0.7426 Time: 0m 1s
# val Loss: 0.0694 Acc:0.7624 Time: 0m 0s
#
# Epoch 12/79
# ----------
# train Loss: 0.1270 Acc:0.7624 Time: 0m 1s
# val Loss: 0.1076 Acc:0.5941 Time: 0m 0s
#
# Epoch 13/79
# ----------
# train Loss: 0.1100 Acc:0.7822 Time: 0m 1s
# val Loss: 0.0539 Acc:0.8614 Time: 0m 0s
#
# Epoch 14/79
# ----------
# train Loss: 0.0828 Acc:0.8614 Time: 0m 1s
# val Loss: 0.0895 Acc:0.7822 Time: 0m 0s
#
# Epoch 15/79
# ----------
# Learning rate is changed to 0.0007290000000000002
# train Loss: 0.0740 Acc:0.9010 Time: 0m 1s
# val Loss: 0.0336 Acc:0.8911 Time: 0m 0s
#
# Epoch 16/79
# ----------
# train Loss: 0.0704 Acc:0.8515 Time: 0m 1s
# val Loss: 0.2152 Acc:0.4554 Time: 0m 0s
#
# Epoch 17/79
# ----------
# train Loss: 0.0622 Acc:0.8911 Time: 0m 1s
# val Loss: 0.2185 Acc:0.5743 Time: 0m 0s
#
# Epoch 18/79
# ----------
# train Loss: 0.1692 Acc:0.8317 Time: 0m 1s
# val Loss: 0.1018 Acc:0.7525 Time: 0m 0s
#
# Epoch 19/79
# ----------
# train Loss: 0.0898 Acc:0.8911 Time: 0m 1s
# val Loss: 0.0619 Acc:0.8218 Time: 0m 0s
#
# Epoch 20/79
# ----------
# Learning rate is changed to 0.0006561000000000001
# train Loss: 0.0986 Acc:0.8515 Time: 0m 1s
# val Loss: 0.0535 Acc:0.8515 Time: 0m 0s
#
# Epoch 21/79
# ----------
# train Loss: 0.0400 Acc:0.9604 Time: 0m 1s
# val Loss: 0.0891 Acc:0.7822 Time: 0m 0s
#
# Epoch 22/79
# ----------
# train Loss: 0.0657 Acc:0.9010 Time: 0m 1s
# val Loss: 0.0872 Acc:0.6931 Time: 0m 0s
#
# Epoch 23/79
# ----------
# train Loss: 0.0513 Acc:0.9307 Time: 0m 1s
# val Loss: 0.0236 Acc:0.9505 Time: 0m 0s
#
# Epoch 24/79
# ----------
# train Loss: 0.0277 Acc:0.9604 Time: 0m 1s
# val Loss: 0.0357 Acc:0.9109 Time: 0m 0s
#
# Epoch 25/79
# ----------
# Learning rate is changed to 0.00059049
# train Loss: 0.0738 Acc:0.9406 Time: 0m 1s
# val Loss: 0.0189 Acc:0.9307 Time: 0m 0s
#
# Epoch 26/79
# ----------
# train Loss: 0.0455 Acc:0.9505 Time: 0m 1s
# val Loss: 0.0114 Acc:0.9901 Time: 0m 0s
#
# Epoch 27/79
# ----------
# train Loss: 0.0176 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0319 Acc:0.9010 Time: 0m 0s
#
# Epoch 28/79
# ----------
# train Loss: 0.0070 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0021 Acc:1.0000 Time: 0m 0s
#
# Epoch 29/79
# ----------
# train Loss: 0.0059 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0033 Acc:1.0000 Time: 0m 0s
#
# Epoch 30/79
# ----------
# Learning rate is changed to 0.000531441
# train Loss: 0.0090 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0012 Acc:1.0000 Time: 0m 0s
#
# Epoch 31/79
# ----------
# train Loss: 0.0200 Acc:0.9604 Time: 0m 1s
# val Loss: 0.0219 Acc:0.9505 Time: 0m 0s
#
# Epoch 32/79
# ----------
# train Loss: 0.0095 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0079 Acc:0.9901 Time: 0m 0s
#
# Epoch 33/79
# ----------
# train Loss: 0.0551 Acc:0.9406 Time: 0m 1s
# val Loss: 0.0180 Acc:0.9802 Time: 0m 0s
#
# Epoch 34/79
# ----------
# train Loss: 0.0866 Acc:0.8911 Time: 0m 1s
# val Loss: 0.0514 Acc:0.8515 Time: 0m 0s
#
# Epoch 35/79
# ----------
# Learning rate is changed to 0.0004782969000000001
# train Loss: 0.0499 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0096 Acc:0.9901 Time: 0m 0s
#
# Epoch 36/79
# ----------
# train Loss: 0.0350 Acc:0.9307 Time: 0m 1s
# val Loss: 0.0330 Acc:0.9604 Time: 0m 0s
#
# Epoch 37/79
# ----------
# train Loss: 0.0145 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0145 Acc:0.9802 Time: 0m 0s
#
# Epoch 38/79
# ----------
# train Loss: 0.0254 Acc:0.9505 Time: 0m 1s
# val Loss: 0.0024 Acc:1.0000 Time: 0m 0s
#
# Epoch 39/79
# ----------
# train Loss: 0.0063 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0012 Acc:1.0000 Time: 0m 0s
#
# Epoch 40/79
# ----------
# Learning rate is changed to 0.0004304672100000001
# train Loss: 0.0201 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0095 Acc:0.9901 Time: 0m 0s
#
# Epoch 41/79
# ----------
# train Loss: 0.0094 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0427 Acc:0.9010 Time: 0m 0s
#
# Epoch 42/79
# ----------
# train Loss: 0.0253 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0138 Acc:0.9703 Time: 0m 0s
#
# Epoch 43/79
# ----------
# train Loss: 0.0262 Acc:0.9505 Time: 0m 1s
# val Loss: 0.0093 Acc:0.9802 Time: 0m 0s
#
# Epoch 44/79
# ----------
# train Loss: 0.0170 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0036 Acc:1.0000 Time: 0m 0s
#
# Epoch 45/79
# ----------
# Learning rate is changed to 0.0003874204890000001
# train Loss: 0.0087 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0007 Acc:1.0000 Time: 0m 0s
#
# Epoch 46/79
# ----------
# train Loss: 0.0073 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0009 Acc:1.0000 Time: 0m 0s
#
# Epoch 47/79
# ----------
# train Loss: 0.0122 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0006 Acc:1.0000 Time: 0m 0s
#
# Epoch 48/79
# ----------
# train Loss: 0.0043 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0007 Acc:1.0000 Time: 0m 0s
#
# Epoch 49/79
# ----------
# train Loss: 0.0117 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0006 Acc:1.0000 Time: 0m 0s
#
# Epoch 50/79
# ----------
# Learning rate is changed to 0.0003486784401000001
# train Loss: 0.0030 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 51/79
# ----------
# train Loss: 0.0037 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 52/79
# ----------
# train Loss: 0.0045 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0185 Acc:0.9604 Time: 0m 0s
#
# Epoch 53/79
# ----------
# train Loss: 0.0054 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0106 Acc:0.9901 Time: 0m 0s
#
# Epoch 54/79
# ----------
# train Loss: 0.0050 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0008 Acc:1.0000 Time: 0m 0s
#
# Epoch 55/79
# ----------
# Learning rate is changed to 0.0003138105960900001
# train Loss: 0.0038 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 56/79
# ----------
# train Loss: 0.0042 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 57/79
# ----------
# train Loss: 0.0055 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 58/79
# ----------
# train Loss: 0.0074 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 59/79
# ----------
# train Loss: 0.0022 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 60/79
# ----------
# Learning rate is changed to 0.0002824295364810001
# train Loss: 0.0067 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 61/79
# ----------
# train Loss: 0.0078 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 62/79
# ----------
# train Loss: 0.0050 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 63/79
# ----------
# train Loss: 0.0015 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 64/79
# ----------
# train Loss: 0.0038 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 65/79
# ----------
# Learning rate is changed to 0.0002541865828329001
# train Loss: 0.0047 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 66/79
# ----------
# train Loss: 0.0009 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 67/79
# ----------
# train Loss: 0.0010 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 68/79
# ----------
# train Loss: 0.0019 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 69/79
# ----------
# train Loss: 0.0019 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 70/79
# ----------
# Learning rate is changed to 0.0002287679245496101
# train Loss: 0.0005 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 71/79
# ----------
# train Loss: 0.0026 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 72/79
# ----------
# train Loss: 0.0025 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 73/79
# ----------
# train Loss: 0.0281 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 74/79
# ----------
# train Loss: 0.0105 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 75/79
# ----------
# Learning rate is changed to 0.0002058911320946491
# train Loss: 0.0055 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 76/79
# ----------
# train Loss: 0.0035 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 77/79
# ----------
# train Loss: 0.0065 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 78/79
# ----------
# train Loss: 0.0178 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 79/79
# ----------
# train Loss: 0.0022 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Training completion in 1m 52s
# Best validation accuracy is 1.0000
# save mode

# %%
print(history)
# Out:
# {'train': [{'mode': 'train', 'epoch': 0, 'epoch_loss': 0.2035350922275992, 'epoch_accuracy': 0.6470588235294118, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 1, 'epoch_loss': 0.10487604579504799, 'epoch_accuracy': 0.7941176470588235, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 2, 'epoch_loss': 0.10616400487282697, 'epoch_accuracy': 0.7794117647058824, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 3, 'epoch_loss': 0.0854384550715194, 'epoch_accuracy': 0.8235294117647058, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 4, 'epoch_loss': 0.09111955498947817, 'epoch_accuracy': 0.8382352941176471, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 5, 'epoch_loss': 0.07314416897647522, 'epoch_accuracy': 0.8823529411764706, 'learing_rate': 0.0009000000000000001}, {'mode': 'train', 'epoch': 6, 'epoch_loss': 0.07091160567806047, 'epoch_accuracy': 0.8382352941176471, 'learing_rate': 0.0009000000000000001}, {'mode': 'train', 'epoch': 7, 'epoch_loss': 0.08407711949856843, 'epoch_accuracy': 0.8235294117647058, 'learing_rate': 0.0009000000000000001}, {'mode': 'train', 'epoch': 8, 'epoch_loss': 0.07686856827315162, 'epoch_accuracy': 0.7941176470588235, 'learing_rate': 0.0009000000000000001}, {'mode': 'train', 'epoch': 9, 'epoch_loss': 0.09725816723178415, 'epoch_accuracy': 0.75, 'learing_rate': 0.0009000000000000001}, {'mode': 'train', 'epoch': 10, 'epoch_loss': 0.06375367347808446, 'epoch_accuracy': 0.8970588235294118, 'learing_rate': 0.0008100000000000001}, {'mode': 'train', 'epoch': 11, 'epoch_loss': 0.06814382400582819, 'epoch_accuracy': 0.8676470588235294, 'learing_rate': 0.0008100000000000001}, {'mode': 'train', 'epoch': 12, 'epoch_loss': 0.07036378618110628, 'epoch_accuracy': 0.8676470588235294, 'learing_rate': 0.0008100000000000001}, {'mode': 'train', 'epoch': 13, 'epoch_loss': 0.06522324089618291, 'epoch_accuracy': 0.8676470588235294, 'learing_rate': 0.0008100000000000001}, {'mode': 'train', 'epoch': 14, 'epoch_loss': 0.05512952212901676, 'epoch_accuracy': 0.8970588235294118, 'learing_rate': 0.0008100000000000001}, {'mode': 'train', 'epoch': 15, 'epoch_loss': 0.08383639836136032, 'epoch_accuracy': 0.8382352941176471, 'learing_rate': 0.0007290000000000002}, {'mode': 'train', 'epoch': 16, 'epoch_loss': 0.08220000269220155, 'epoch_accuracy': 0.8970588235294118, 'learing_rate': 0.0007290000000000002}, {'mode': 'train', 'epoch': 17, 'epoch_loss': 0.053883973947342706, 'epoch_accuracy': 0.8970588235294118, 'learing_rate': 0.0007290000000000002}, {'mode': 'train', 'epoch': 18, 'epoch_loss': 0.04492888040840626, 'epoch_accuracy': 0.8970588235294118, 'learing_rate': 0.0007290000000000002}, {'mode': 'train', 'epoch': 19, 'epoch_loss': 0.04792944254244075, 'epoch_accuracy': 0.9117647058823529, 'learing_rate': 0.0007290000000000002}, {'mode': 'train', 'epoch': 20, 'epoch_loss': 0.04219825631555389, 'epoch_accuracy': 0.9117647058823529, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 21, 'epoch_loss': 0.029663996277924848, 'epoch_accuracy': 0.9264705882352942, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 22, 'epoch_loss': 0.04103850080248188, 'epoch_accuracy': 0.9117647058823529, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 23, 'epoch_loss': 0.09312924622174572, 'epoch_accuracy': 0.8823529411764706, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 24, 'epoch_loss': 0.02557321832350948, 'epoch_accuracy': 0.9705882352941176, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 25, 'epoch_loss': 0.025014481945511174, 'epoch_accuracy': 0.9852941176470589, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 26, 'epoch_loss': 0.03975050362265285, 'epoch_accuracy': 0.8676470588235294, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 27, 'epoch_loss': 0.02424102186855367, 'epoch_accuracy': 0.9411764705882353, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 28, 'epoch_loss': 0.036583245101877875, 'epoch_accuracy': 0.941176 ...

# %%
train_epoch = []
train_loss = []
train_acc = []
learning_rate_used = []
for i in history['train']:
    train_epoch.append(i['epoch'])
    train_loss.append(i['epoch_loss'])
    train_acc.append(i['epoch_accuracy'])
    learning_rate_used.append(i['learing_rate'])

# %%
fig = plt.figure(figsize=(10, 12))

plt.subplot(311)
plt.plot(train_epoch, train_loss,'g-', linewidth = 1.5)
plt.title('training loss vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('loss', fontsize = 15)
plt.tight_layout()
plt.subplot(312)
plt.plot(train_epoch, train_acc,'r--',linewidth = 1.5)
plt.title('training accuracy vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('accuracy', fontsize = 15)
plt.tight_layout()
plt.subplot(313)
plt.plot(train_epoch, learning_rate_used,'b-.',linewidth = 1.5)
plt.title('learning rate used vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('learning rate', fontsize = 15)
plt.tight_layout()
fig.savefig('all_figures.png')

# %%
val_epoch = []
val_acc = []
val_loss = []
for i in history['val']:
    val_epoch.append(i['epoch'])
    val_loss.append(i['epoch_loss'])
    val_acc.append(i['epoch_accuracy'])

# %%
fig = plt.figure(figsize=(10, 8))

plt.subplot(211)
plt.plot(val_epoch, val_loss,'g-',linewidth = 1.5)
plt.title('val loss vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('loss', fontsize = 15)
plt.tight_layout()
plt.subplot(212)
plt.plot(val_epoch, val_acc,'r--',linewidth = 1.5)
plt.title('val accuracy vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('accuracy', fontsize = 15)
plt.tight_layout()

fig.savefig('all_figures_val_gnet.png')
