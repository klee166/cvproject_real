# %%
import torch
from torch import autograd
import torch.nn.functional as F
from torch.autograd import Variable
import torch.nn as nn
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
import copy
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torchvision import datasets
import cv2

# %%
in_height = 120
in_width = 120
in_channels = 3

# %%
##Divide ConvNet into multiple parts 
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return F.relu(x, inplace=True)

# %%
## conv layer (stem layer)
class _Stem(nn.Module): 
    def __init__(self):
        super(_Stem, self).__init__()
        self.stem = nn.Sequential(
                        BasicConv2d(in_channels, 64, kernel_size=7, padding=2, stride=2),
                        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                        BasicConv2d(64, 64, kernel_size=1),
                        BasicConv2d(64, 192, kernel_size=3, padding=1),
                        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                    )

    def forward(self, x):
        x = self.stem(x)

        return x

# %%
## auxiliary layer for vanishing gradient
class _Auxiliary_Classifiers(nn.Module):
    def __init__(self, num_fts):
        super(_Auxiliary_Classifiers, self).__init__()
        self.aux_classifier = nn.Sequential(
                                    nn.AvgPool2d(kernel_size=5, stride=3, padding=2),
                                    BasicConv2d(num_fts, 128, kernel_size=1),
                                )

        self.classifier = nn.Sequential(
                                nn.Linear(5 * 5 * 128, 1024),
                                nn.Dropout(p=0.7),
                                nn.Linear(1024, 3)
                            )

    def forward(self, x):
        x = self.aux_classifier(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)

        return x

# %%
class _Inception_Module(nn.Module):
    def __init__(self, conv1x1, conv1x1_reduce_3, conv1x1_reduce_5,
                        conv3x3, conv5x5, conv1x1_reduce_pool,
                        num_fts):
        super(_Inception_Module, self).__init__()

        self.conv1x1_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1, kernel_size=1),
                                )

        self.conv3x3_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1_reduce_3, kernel_size=1),
                                    BasicConv2d(conv1x1_reduce_3, conv3x3, kernel_size=3, padding=1),
                                )

        self.conv5x5_branch = nn.Sequential(
                                    BasicConv2d(num_fts, conv1x1_reduce_5, kernel_size=1),
                                    BasicConv2d(conv1x1_reduce_5, conv5x5, kernel_size=5, padding=2),
                                )

        self.pool_branch = nn.Sequential(
                                    nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
                                    BasicConv2d(num_fts, conv1x1_reduce_pool, kernel_size=1),
                                )

    def forward(self, x):
        x1x1 = self.conv1x1_branch(x)
        x3x3 = self.conv3x3_branch(x)
        x5x5 = self.conv5x5_branch(x)
        xpool = self.pool_branch(x)

        x = torch.cat([x1x1, x3x3, x5x5, xpool], 1)

        return x

# %%
class GoogleLeNet(nn.Module):
    def __init__(self):
        super(GoogleLeNet, self).__init__()
        self.features1 = nn.Sequential(
                            _Stem(),
                            _Inception_Module(conv1x1=64, conv1x1_reduce_3=96, conv3x3=128, 
                                conv1x1_reduce_5=16, conv5x5=32, conv1x1_reduce_pool=32, 
                                num_fts=192),
                            _Inception_Module(conv1x1=128, conv1x1_reduce_3=128, conv3x3=192, 
                                conv1x1_reduce_5=32, conv5x5=96, conv1x1_reduce_pool=64, 
                                num_fts=256),
                            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                            _Inception_Module(conv1x1=192, conv1x1_reduce_3=96, conv3x3=208, 
                                conv1x1_reduce_5=16, conv5x5=48, conv1x1_reduce_pool=64, 
                                num_fts=480)
                        )

        self.features2 = nn.Sequential(
                            _Inception_Module(conv1x1=160, conv1x1_reduce_3=112, conv3x3=224, 
                                conv1x1_reduce_5=24, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512),
                            _Inception_Module(conv1x1=128, conv1x1_reduce_3=128, conv3x3=256, 
                                conv1x1_reduce_5=24, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512),
                            _Inception_Module(conv1x1=112, conv1x1_reduce_3=144, conv3x3=288, 
                                conv1x1_reduce_5=32, conv5x5=64, conv1x1_reduce_pool=64, 
                                num_fts=512)
                        )

        self.features3 = nn.Sequential(
                            _Inception_Module(conv1x1=256, conv1x1_reduce_3=160, conv3x3=320, 
                                conv1x1_reduce_5=32, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=528),
                            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                            _Inception_Module(conv1x1=256, conv1x1_reduce_3=160, conv3x3=320, 
                                conv1x1_reduce_5=32, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=832),
                            _Inception_Module(conv1x1=384, conv1x1_reduce_3=192, conv3x3=384, 
                                conv1x1_reduce_5=48, conv5x5=128, conv1x1_reduce_pool=128, 
                                num_fts=832)
                        )
        
        self.Aux1 = _Auxiliary_Classifiers(num_fts=512)
        self.Aux2 = _Auxiliary_Classifiers(num_fts=528)

        self.fc = nn.Linear(1024, 3)
    def forward(self, x):
        x = self.features1(x)

        if self.training:
            aux1 = self.Aux1(x)

        x = self.features2(x)

        if self.training:
            aux2 = self.Aux2(x)

        x = self.features3(x)
        x = F.avg_pool2d(x, kernel_size=7)
        x = x.view(-1 ,1024)
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.fc(x)
        
        if self.training:
            return x, aux1, aux2
        else:
            return x

# %%
def train(model, criterion, optimizer, lr_scheduler, dsets_loader, dset_sizes, lr = 0.001, num_epochs = 20):
    since = time.time()
    use_model = model
    best_acc = 0.0
    #accuracy = []
    #epoch_num = []
    #loss_arr = []
    history = {
        x :[]
        for x in ['train','val']
    }
    
    for i in range(num_epochs):
        print('Epoch {}/{}'.format(i, num_epochs - 1))
        print('-'*10)
        for mode in ['train','val']:
            start = time.time()
            
            if mode == 'train':
                optimizer = lr_scheduler(optimizer, i, init_lr = lr)
                model.train()
            else:
                model.eval()
            
            running_loss = 0.0
            running_corrects = 0
            
            for data in dsets_loader[mode]:
                
                inputs, labels = data
                #print(inputs)
                inputs_, labels_ = Variable(inputs.cuda()), Variable(labels.cuda())
                
                optimizer.zero_grad()
                
                
                
                if mode == 'train':
                    o1, o2, o3 = model(inputs_)
                    _, preds = torch.max(o1.data, 1)
                
                    loss1 = criterion(o1, labels_)
                    loss2 = criterion(o2, labels_)
                    loss3 = criterion(o3, labels_)

                    loss = loss1 + 0.3 * (loss2 + loss3)
                   
                else:
                    outputs = model(inputs_)
                    _, preds = torch.max(outputs.data, 1)
                    loss = criterion(outputs, labels_)
                if mode == 'train':
                    loss.backward()
                    optimizer.step()
                running_loss += loss.data[0]
                running_corrects += torch.sum(preds == labels_.data)
                
            epoch_loss = running_loss / dset_sizes[mode]
            #loss_arr.append(epoch_loss)
            epoch_acc = running_corrects / dset_sizes[mode]
            #accuracy.append(epoch_acc)
            epoch_time = time.time() - start
            
            history_dict =  {
                'mode':mode,
                'epoch':i,
                'epoch_loss': epoch_loss,
                'epoch_accuracy': epoch_acc,
                'learing_rate':optimizer.state_dict()['param_groups'][0]['lr']
                
            }
            
            history[mode].append(history_dict)
            
            print('{} Loss: {:.4f} Acc:{:.4f} Time: {:.0f}m {:.0f}s'.format(mode, epoch_loss, epoch_acc, epoch_time//60, epoch_time%60))
            
            if mode == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model)
        print()
    time_elapsed = time.time() - since
    
    print('Training completion in {:.0f}m {:.0f}s'.format(time_elapsed//60, time_elapsed%60))
    print('Best validation accuracy is {:.4f}'.format(best_acc))
    
    print('save mode')
    ##here I want to save the history of the process in order to debug
    with open('history.pickle','wb') as f:
        pickle.dump(history, f)
    
    return best_model, best_acc, history

# %%
#add scheduler to better control learning rate 
def exp_lr_scheduler(optimizer, epoch, init_lr = 0.001, lr_decay_epoch = 5):
    lr = init_lr * (0.9 ** (epoch // lr_decay_epoch))
    
    if epoch % lr_decay_epoch == 0:
        print('Learning rate is changed to {}'.format(lr))
    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return optimizer

# %%
net = GoogleLeNet().cuda()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), weight_decay = 0.0005)
lr_scheduler = exp_lr_scheduler
lr = 0.001

# %%
def load_data(train_path, val_path=None):
    if val_path is None:
        val_path = train_path
    train_transfrom = transforms.Compose([
        
        transforms.Scale(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.255])
                ])

    val_transfrom = transforms.Compose([
        transforms.Scale(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.255])
                ])
    dsets = {
        'train': datasets.ImageFolder(train_path, train_transfrom),
        'val': datasets.ImageFolder(val_path, val_transfrom)
    }
    dset_loaders = {
        x: torch.utils.data.DataLoader(dsets[x], batch_size=7, shuffle=True, num_workers=4)
        for x in ['train', 'val']
    }
    dset_sizes = {
        x: len(dsets[x])
        for x in ['train', 'val']
    }
    
    dset_classes = dsets['train'].classes
    return dset_loaders, dset_sizes, dset_classes

# %%
train_file = './alzheimers'
val_file = ''
##load data
#dset_loaders, dset_sizes, dset_classes = mri_loader.load_data(train_path=train_path, val_path=val_path)

# %%
dset_loaders, dset_sizes, dset_classes = load_data(train_path=train_file)

print(dset_sizes)
print(dset_classes)
print(dset_loaders)
# Out:
# {'train': 101, 'val': 101}
# ['label_0', 'label_1', 'label_2']
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x7f10c10920b8>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x7f10c1092f28>}

# %%
best_model, best_acc, history = train(net, criterion, optimizer, lr_scheduler,
Acc:0.9901 Time: 0m 1s
# val Loss: 0.0018 Acc:1.0000 Time: 0m 0s
#
# Epoch 38/79
# ----------
# train Loss: 0.0181 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0061 Acc:1.0000 Time: 0m 0s
#
# Epoch 39/79
# ----------
# train Loss: 0.0203 Acc:0.9505 Time: 0m 1s
# val Loss: 0.0798 Acc:0.8713 Time: 0m 0s
#
# Epoch 40/79
# ----------
# Learning rate is changed to 0.0004304672100000001
# train Loss: 0.0043 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0058 Acc:0.9901 Time: 0m 0s
#
# Epoch 41/79
# ----------
# train Loss: 0.0196 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0492 Acc:0.8614 Time: 0m 0s
#
# Epoch 42/79
# ----------
# train Loss: 0.0373 Acc:0.9307 Time: 0m 1s
# val Loss: 0.0035 Acc:0.9901 Time: 0m 0s
#
# Epoch 43/79
# ----------
# train Loss: 0.0314 Acc:0.9406 Time: 0m 1s
# val Loss: 0.0008 Acc:1.0000 Time: 0m 0s
#
# Epoch 44/79
# ----------
# train Loss: 0.0101 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0045 Acc:1.0000 Time: 0m 0s
#
# Epoch 45/79
# ----------
# Learning rate is changed to 0.0003874204890000001
# train Loss: 0.0064 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0015 Acc:1.0000 Time: 0m 0s
#
# Epoch 46/79
# ----------
# train Loss: 0.0055 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0009 Acc:1.0000 Time: 0m 0s
#
# Epoch 47/79
# ----------
# train Loss: 0.0105 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0031 Acc:0.9901 Time: 0m 0s
#
# Epoch 48/79
# ----------
# train Loss: 0.0262 Acc:0.9505 Time: 0m 1s
# val Loss: 0.0013 Acc:1.0000 Time: 0m 0s
#
# Epoch 49/79
# ----------
# train Loss: 0.0139 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0044 Acc:1.0000 Time: 0m 0s
#
# Epoch 50/79
# ----------
# Learning rate is changed to 0.0003486784401000001
# train Loss: 0.0074 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0007 Acc:1.0000 Time: 0m 0s
#
# Epoch 51/79
# ----------
# train Loss: 0.0038 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 52/79
# ----------
# train Loss: 0.0058 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 53/79
# ----------
# train Loss: 0.0086 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 54/79
# ----------
# train Loss: 0.0069 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 55/79
# ----------
# Learning rate is changed to 0.0003138105960900001
# train Loss: 0.0038 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0012 Acc:1.0000 Time: 0m 0s
#
# Epoch 56/79
# ----------
# train Loss: 0.0080 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 57/79
# ----------
# train Loss: 0.0110 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 58/79
# ----------
# train Loss: 0.0093 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 59/79
# ----------
# train Loss: 0.0058 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 60/79
# ----------
# Learning rate is changed to 0.0002824295364810001
# train Loss: 0.0091 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 61/79
# ----------
# train Loss: 0.0108 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 62/79
# ----------
# train Loss: 0.0028 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0010 Acc:1.0000 Time: 0m 0s
#
# Epoch 63/79
# ----------
# train Loss: 0.0149 Acc:0.9802 Time: 0m 1s
# val Loss: 0.0793 Acc:0.8713 Time: 0m 0s
#
# Epoch 64/79
# ----------
# train Loss: 0.0147 Acc:0.9703 Time: 0m 1s
# val Loss: 0.0010 Acc:1.0000 Time: 0m 0s
#
# Epoch 65/79
# ----------
# Learning rate is changed to 0.0002541865828329001
# train Loss: 0.0052 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 66/79
# ----------
# train Loss: 0.0131 Acc:0.9604 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 67/79
# ----------
# train Loss: 0.0029 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0004 Acc:1.0000 Time: 0m 0s
#
# Epoch 68/79
# ----------
# train Loss: 0.0074 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0003 Acc:1.0000 Time: 0m 0s
#
# Epoch 69/79
# ----------
# train Loss: 0.0017 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0006 Acc:1.0000 Time: 0m 0s
#
# Epoch 70/79
# ----------
# Learning rate is changed to 0.0002287679245496101
# train Loss: 0.0068 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 71/79
# ----------
# train Loss: 0.0066 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 72/79
# ----------
# train Loss: 0.0054 Acc:0.9901 Time: 0m 1s
# val Loss: 0.0012 Acc:1.0000 Time: 0m 0s
#
# Epoch 73/79
# ----------
# train Loss: 0.0027 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0005 Acc:1.0000 Time: 0m 0s
#
# Epoch 74/79
# ----------
# train Loss: 0.0024 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Epoch 75/79
# ----------
# Learning rate is changed to 0.0002058911320946491
# train Loss: 0.0015 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 76/79
# ----------
# train Loss: 0.0021 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 77/79
# ----------
# train Loss: 0.0029 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 78/79
# ----------
# train Loss: 0.0011 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0001 Acc:1.0000 Time: 0m 0s
#
# Epoch 79/79
# ----------
# train Loss: 0.0022 Acc:1.0000 Time: 0m 1s
# val Loss: 0.0002 Acc:1.0000 Time: 0m 0s
#
# Training completion in 1m 53s
# Best validation accuracy is 1.0000
# save mode

# %%
print(history)
# Out:
# {'train': [{'mode': 'train', 'epoch': 0, 'epoch_loss': 0.22394328542275005, 'epoch_accuracy': 0.6732673267326733, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 1, 'epoch_loss': 0.19484274694235018, 'epoch_accuracy': 0.6732673267326733, 'learing_rate': 0.001}, {'mode': 'train', 'epoch': 2, 'epoch_loss': 0.16596726763366473, 'epoch_accuracy': 0.7227722772277227, 'learing_rate': 0.001
learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 23, 'epoch_loss': 0.0525953283551896, 'epoch_accuracy': 0.8811881188118812, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 24, 'epoch_loss': 0.08547260103249314, 'epoch_accuracy': 0.801980198019802, 'learing_rate': 0.0006561000000000001}, {'mode': 'train', 'epoch': 25, 'epoch_loss': 0.030358271876184065, 'epoch_accuracy': 0.9405940594059405, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 26, 'epoch_loss': 0.024181786039383105, 'epoch_accuracy': 0.9603960396039604, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 27, 'epoch_loss': 0.021639455183602795, 'epoch_accuracy': 0.9702970297029703, 'learing_rate': 0.00059049}, {'mode': 'train', 'epoch': 28, 'epoch_loss': 0.01865009295910892, 'epoch_accuracy ...

# %%
train_epoch = []
train_loss = []
train_acc = []
learning_rate_used = []
for i in history['train']:
    train_epoch.append(i['epoch'])
    train_loss.append(i['epoch_loss'])
    train_acc.append(i['epoch_accuracy'])
    learning_rate_used.append(i['learing_rate'])

# %%
fig = plt.figure(figsize=(10, 12))

plt.subplot(311)
plt.plot(train_epoch, train_loss,'g-', linewidth = 1.5)
plt.title('training loss vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('loss', fontsize = 15)
plt.tight_layout()
plt.subplot(312)
plt.plot(train_epoch, train_acc,'r--',linewidth = 1.5)
plt.title('training accuracy vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('accuracy', fontsize = 15)
plt.tight_layout()
plt.subplot(313)
plt.plot(train_epoch, learning_rate_used,'b-.',linewidth = 1.5)
plt.title('learning rate used vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('learning rate', fontsize = 15)
plt.tight_layout()
fig.savefig('all_figures.png')

# %%
val_epoch = []
val_acc = []
val_loss = []
for i in history['val']:
    val_epoch.append(i['epoch'])
    val_loss.append(i['epoch_loss'])
    val_acc.append(i['epoch_accuracy'])

# %%
fig = plt.figure(figsize=(10, 8))

plt.subplot(211)
plt.plot(val_epoch, val_loss,'g-',linewidth = 1.5)
plt.title('val loss vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('loss', fontsize = 15)
plt.tight_layout()
plt.subplot(212)
plt.plot(val_epoch, val_acc,'r--',linewidth = 1.5)
plt.title('val accuracy vs. epoch',fontsize=20)
plt.xlabel('epoch', fontsize = 15)
plt.ylabel('accuracy', fontsize = 15)
plt.tight_layout()

fig.savefig('all_figures_val_gnet.png')

# %%
print(best_model)
# Out:
# GoogleLeNet (
#   (features1): Sequential (
#     (0): _Stem (
#       (stem): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#         (2): BasicConv2d (
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (3): BasicConv2d (
#           (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (4): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (4): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (features2): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (features3): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (Aux1): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
#   (Aux2): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
#   (fc): Linear (1024 -> 3)
# )

# %%
params = list(best_model.parameters())

# %%
for p in params:
    print(p.size())
# Out:
# torch.Size([64, 3, 7, 7])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 64, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([192, 64, 3, 3])
# torch.Size([192])
# torch.Size([192])
# torch.Size([64, 192, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([96, 192, 1, 1])
# torch.Size([96])
# torch.Size([96])
# torch.Size([128, 96, 3, 3])
# torch.Size([128])
# torch.Size([128])
# torch.Size([16, 192, 1, 1])
# torch.Size([16])
# torch.Size([16])
# torch.Size([32, 16, 5, 5])
# torch.Size([32])
# torch.Size([32])
# torch.Size([32, 192, 1, 1])
# torch.Size([32])
# torch.Size([32])
# torch.Size([128, 256, 1, 1])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128, 256, 1, 1])
# torch.Size([128])
# torch.Size([128])
# torch.Size([192, 128, 3, 3])
# torch.Size([192])
# torch.Size([192])
# torch.Size([32, 256, 1, 1])
# torch.Size([32])
# torch.Size([32])
# torch.Size([96, 32, 5, 5])
# torch.Size([96])
# torch.Size([96])
# torch.Size([64, 256, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([192, 480, 1, 1])
# torch.Size([192])
# torch.Size([192])
# torch.Size([96, 480, 1, 1])
# torch.Size([96])
# torch.Size([96])
# torch.Size([208, 96, 3, 3])
# torch.Size([208])
# torch.Size([208])
# torch.Size([16, 480, 1, 1])
# torch.Size([16])
# torch.Size([16])
# torch.Size([48, 16, 5, 5])
# torch.Size([48])
# torch.Size([48])
# torch.Size([64, 480, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([160, 512, 1, 1])
# torch.Size([160])
# torch.Size([160])
# torch.Size([112, 512, 1, 1])
# torch.Size([112])
# torch.Size([112])
# torch.Size([224, 112, 3, 3])
# torch.Size([224])
# torch.Size([224])
# torch.Size([24, 512, 1, 1])
# torch.Size([24])
# torch.Size([24])
# torch.Size([64, 24, 5, 5])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 512, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([128, 512, 1, 1])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128, 512, 1, 1])
# torch.Size([128])
# torch.Size([128])
# torch.Size([256, 128, 3, 3])
# torch.Size([256])
# torch.Size([256])
# torch.Size([24, 512, 1, 1])
# torch.Size([24])
# torch.Size([24])
# torch.Size([64, 24, 5, 5])
# torch.Size([64])
# torch.Size([64])
# torch.Size([
            print(m.weight.data)
            final_weight = m.weight.data.cpu().numpy()
# Out:
#  1.5122e-02 -2.6092e-02 -2.5943e-02  ...  -7.6151e-03 -3.2051e-02 -2.4884e-02
#  2.3848e-02 -3.3314e-02  1.7902e-02  ...   2.2983e-02 -3.5320e-02 -3.1554e-02
# -2.7002e-02  3.9717e-02 -1.3763e-02  ...  -1.5119e-02  1.9278e-02  2.4153e-02
# [torch.cuda.FloatTensor of size 3x1024 (GPU 0)]

# %%
print(final_weight.shape)
plt.figure(1)
plt.imshow(final_weight[0,:].reshape(32,32))
plt.figure(2)
plt.imshow(final_weight[1,:].reshape(32,32))
plt.figure(3)
plt.imshow(final_weight[2,:].reshape(32,32))
# Out:
# (3, 1024)

# %%
print(best_model.modules)
# Out:
# <bound method Module.modules of GoogleLeNet (
#   (features1): Sequential (
#     (0): _Stem (
#       (stem): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#         (2): BasicConv2d (
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (3): BasicConv2d (
#           (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (4): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (4): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (features2): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (features3): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (Aux1): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
#   (Aux2): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
#   (fc): Linear (1024 -> 3)
# )>

# %%
val_transfrom = transforms.Compose([
        transforms.Scale(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.255])
                ])

# %%
from PIL import Image

# %%
test_img = Image.open('./alzheimers/label_0/OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc_cor_110.jpg')

# %%
print(test_img.size)
# Out:
# (176, 176)

# %%
img_to_use = val_transfrom(test_img)

# %%
img_to_use
# Out:
# ( 0 ,.,.) =
#  -2.1179 -2.1179 -2.1179  ...  -2.1179 -2.1179 -2.1179
#  -2.1179 -2.1179 -2.1179  ...  -2.1179 -2.1179 -2.1179
#  -2.1179 -2.1179 -2.1179  ...  -2.1179 -2.1179 -2.1179
#            ...             ⋱             ...
#  -2.0152 -1.9980 -1.9809  ...  -2.1008 -2.1179 -2.1179
#  -1.9809 -1.9638 -1.9295  ...  -2.1008 -2.1179 -2.1179
#  -1.9638 -1.9467 -1.9124  ...  -2.1008 -2.1179 -2.1179
# [torch.FloatTensor of size 1x224x224]

# %%
sd = best_model.state_dict()

# %%
for key, value in sd.items():
    print(key)
# Out:
# features1.0.stem.0.conv.weight
# features1.0.stem.0.bn.weight
# features1.0.stem.0.bn.bias
# features1.0.stem.0.bn.running_mean
# features1.0.stem.0.bn.running_var
# features1.0.stem.2.conv.weight
# features1.0.stem.2.bn.weight
# features1.0.stem.2.bn.bias
# features1.0.stem.2.bn.running_mean
# features1.0.stem.2.bn.running_var
# features1.0.stem.3.conv.weight
# features1.0.stem.3.bn.weight
# features1.0.stem.3.bn.bias
# features1.0.stem.3.bn.running_mean
# features1.0.stem.3.bn.running_var
# features1.1.conv1x1_branch.0.conv.weight
# features1.1.conv1x1_branch.0.bn.weight
# features1.1.conv1x1_branch.0.bn.bias
# features1.1.conv1x1_branch.0.bn.running_mean
# features1.1.conv1x1_branch.0.bn.running_var
# features1.1.conv3x3_branch.0.conv.weight
# features1.1.conv3x3_branch.0.bn.weight
# features1.1.conv3x3_branch.0.bn.bias
# features1.1.conv3x3_branch.0.bn.running_mean
# features1.1.conv3x3_branch.0.bn.running_var
# features1.1.conv3x3_branch.1.conv.weight
# features1.1.conv3x3_branch.1.bn.weight
# features1.1.conv3x3_branch.1.bn.bias
# features1.1.conv3x3_branch.1.bn.running_mean
# features1.1.conv3x3_branch.1.bn.running_var
# features1.1.conv5x5_branch.0.conv.weight
# features1.1.conv5x5_branch.0.bn.weight
# features1.1.conv5x5_branch.0.bn.bias
# features1.1.conv5x5_branch.0.bn.running_mean
# features1.1.conv5x5_branch.0.bn.running_var
# features1.1.conv5x5_branch.1.conv.weight
# features1.1.conv5x5_branch.1.bn.weight
# features1.1.conv5x5_branch.1.bn.bias
# features1.1.conv5x5_branch.1.bn.running_mean
# features1.1.conv5x5_branch.1.bn.running_var
# features1.1.pool_branch.1.conv.weight
# features1.1.pool_branch.1.bn.weight
# features1.1.pool_branch.1.bn.bias
# features1.1.pool_branch.1.bn.running_mean
# features1.1.pool_branch.1.bn.running_var
# features1.2.conv1x1_branch.0.conv.weight
# features1.2.conv1x1_branch.0.bn.weight
# features1.2.conv1x1_branch.0.bn.bias
# features1.2.conv1x1_branch.0.bn.running_mean
# features1.2.conv1x1_branch.0.bn.running_var
# features1.2.conv3x3_branch.0.conv.weight
# features1.2.conv3x3_branch.0.bn.weight
# features1.2.conv3x3_branch.0.bn.bias
# features1.2.conv3x3_branch.0.bn.running_mean
# features1.2.conv3x3_branch.0.bn.running_var
# features1.2.conv3x3_branch.1.conv.weight
# features1.2.conv3x3_branch.1.bn.weight
# features1.2.conv3x3_branch.1.bn.bias
# features1.2.conv3x3_branch.1.bn.running_mean
# features1.2.conv3x3_branch.1.bn.running_var
# features1.2.conv5x5_branch.0.conv.weight
# features1.2.conv5x5_branch.0.bn.weight
# features1.2.conv5x5_branch.0.bn.bias
# features1.2.conv5x5_branch.0.bn.running_mean
# features1.2.conv5x5_branch.0.bn.running_var
# features1.2.conv5x5_branch.1.conv.weight
# features1.2.conv5x5_branch.1.bn.weight
# features1.2.conv5x5_branch.1.bn.bias
# features1.2.conv5x5_branch.1.bn.running_mean
# features1.2.conv5x5_branch.1.bn.running_var
# features1.2.pool_branch.1.conv.weight
# features1.2.pool_branch.1.bn.weight
# features1.2.pool_branch.1.bn.bias
# features1.2.pool_branch.1.bn.running_mean
# features1.2.pool_branch.1.bn.running_var
# features1.4.conv1x1_branch.0.conv.weight
# features1.4.conv1x1_branch.0.bn.weight
# features1.4.conv1x1_branch.0.bn.bias
# features1.4.conv1x1_branch.0.bn.running_mean
# features1.4.conv1x1_branch.0.bn.running_var
# features1.4.conv3x3_branch.0.conv.weight
# features1.4.conv3x3_branch.0.bn.weight
# features1.4.conv3x3_branch.0.bn.bias
# features1.4.conv3x3_branch.0.bn.running_mean
# features1.4.conv3x3_branch.0.bn.running_var
# features1.4.conv3x3_branch.1.conv.weight
# features1.4.conv3x3_branch.1.bn.weight
# features1.4.conv3x3_branch.1.bn.bias
# features1.4.conv3x3_branch.1.bn.running_mean
# features1.4.conv3x3_branch.1.bn.running_var
# features1.4.conv5x5_branch.0.conv.weight
# features1.4.conv5x5_branch.0.bn.weight
# features1.4.conv5x5_branch.0.bn.bias
# features1.4.conv5x5_branch.0.bn.running_mean
# features1.4.conv5x5_branch.0.bn.running_var
# features1.4.conv5x5_branch.1.conv.weight
# features1.4.conv5x5_branch.1.bn.weight
# features1.4.conv5x5_branch.1.bn.bias
# features1.4.conv5x5_branch.1.bn.running_mean
# features1.4.conv5x5_branch.1.bn.running_var
# features1.4.pool_branch.1.conv.weight
# features1.4.pool_branch.1.bn.weight
# features1.4.pool_branch.1.bn.bias
# features1.4.pool_branch.1.bn.running_mean
# features1.4.pool_branch.1.bn.running_var
# features2.0.conv1x1_branch.0.conv.weight
# features2.0.conv1x1_branch.0.bn.weight
# features2.0.conv1x1_branch.0.bn.bias
# features2.0.conv1x1_branch.0.bn.running_mean
# features2.0.conv1x1_branch.0.bn.running_var
# features2.0.conv3x3_branch.0.conv.weight
# features2.0.conv3x3_branch.0.bn.weight
# features2.0.conv3x3_branch.0.bn.bias
# features2.0.conv3x3_branch.0.bn.running_mean
# features2.0.conv3x3_branch.0.bn.running_var
# features2.0.conv3x3_branch.1.conv.weight
# features2.0.conv3x3_branch.1.bn.weight
# features2.0.conv3x3_branch.1.bn.bias
# features2.0.conv3x3_branch.1.bn.running_mean
# features2.0.conv3x3_branch.1.bn.running_var
# features2.0.conv5x5_branch.0.conv.weight
# features2.0.conv5x5_branch.0.bn.weight
# features2.0.conv5x5_branch.0.bn.bias
# features2.0.conv5x5_branch.0.bn.running_mean
# features2.0.conv5x5_branch.0.bn.running_var
# features2.0.conv5x5_branch.1.conv.weight
# features2.0.conv5x5_branch.1.bn.weight
# features2.0.conv5x5_branch.1.bn.bias
# features2.0.conv5x5_branch.1.bn.running_mean
# features2.0.conv5x5_branch.1.bn.running_var
# features2.0.pool_branch.1.conv.weight
# features2.0.pool_branch.1.bn.weight
# features2.0.pool_branch.1.bn.bias
# features2.0.pool_branch.1.bn.running_mean
# features2.0.pool_branch.1.bn.running_var
# features2.1.conv1x1_branch.0.conv.weight
# features2.1.conv1x1_branch.0.bn.weight
# features2.1.conv1x1_branch.0.bn.bias
# features2.1.conv1x1_branch.0.bn.running_mean
# features2.1.conv1x1_branch.0.bn.running_var
# features2.1.conv3x3_branch.0.conv.weight
# features2.1.conv3x3_branch.0.bn.weight
# features2.1.conv3x3_branch.0.bn.bias
# features2.1.conv3x3_branch.0.bn.running_mean
# features2.1.conv3x3_branch.0.bn.running_var
# features2.1.conv3x3_branch.1.conv.weight
# features2.1.conv3x3_branch.1.bn.weight
# features2.1.conv3x3_branch.1.bn.bias
# features2.1.conv3x3_branch.1.bn.running_mean
# features2.1.conv3x3_branch.1.bn.running_var
# features2.1.conv5x5_branch.0.conv.weight
# features2.1.conv5x5_branch.0.bn.weight
# features2.1.conv5x5_branch.0.bn.bias
# features2.1.conv5x5_branch.0.bn.running_mean
# features2.1.conv5x5_branch.0.bn.running_var
# features2.1.conv5x5_branch.1.conv.weight
# features2.1.conv5x5_branch.1.bn.weight
# features2.1.conv5x5_branch.1.bn.bias
# features2.1.conv5x5_branch.1.bn.running_mean
# features2.1.conv5x5_branch.1.bn.running_var
# features2.1.pool_branch.1.conv.weight
# features2.1.pool_branch.1.bn.weight
# features2.1.pool_branch.1.bn.bias
# features2.1.pool_branch.1.bn.running_mean
# features2.1.pool_branch.1.bn.running_var
# features2.2.conv1x1_branch.0.conv.weight
# features2.2.conv1x1_branch.0.bn.weight
# features2.2.conv1x1_branch.0.bn.bias
# features2.2.conv1x1_branch.0.bn.running_mean
# features2.2.conv1x1_branch.0.bn.running_var
# features2.2.conv3x3_branch.0.conv.weight
# features2.2.conv3x3_branch.0.bn.weight
# features2.2.conv3x3_branch.0.bn.bias
# features2.2.conv3x3_branch.0.bn.running_mean
# features2.2.conv3x3_branch.0.bn.running_var
# features2.2.conv3x3_branch.1.conv.weight
# features2.2.conv3x3_branch.1.bn.weight
# features2.2.conv3x3_branch.1.bn.bias
# features2.2.conv3x3_branch.1.bn.running_mean
# features2.2.conv3x3_branch.1.bn.running_var
# features2.2.conv5x5_branch.0.conv.weight
# features2.2.conv5x5_branch.0.bn.weight
# features2.2.conv5x5_branch.0.bn.bias
# features2.2.conv5x5_branch.0.bn.running_mean
# features2.2.conv5x5_branch.0.bn.running_var
# features2.2.conv5x5_branch.1.conv.weight
# features2.2.conv5x5_branch.1.bn.weight
# features2.2.conv5x5_branch.1.bn.bias
# features2.2.conv5x5_branch.1.bn.running_mean
# features2.2.conv5x5_branch.1.bn.running_var
# features2.2.pool_branch.1.conv.weight
# features2.2.pool_branch.1.bn.weight
# features2.2.pool_branch.1.bn.bias
# features2.2.pool_branch.1.bn.running_mean
# features2.2.pool_branch.1.bn.running_var
# features3.0.conv1x1_branch.0.conv.weight
# features3.0.conv1x1_branch.0.bn.weight
# features3.0.conv1x1_branch.0.bn.bias
# features3.0.conv1x1_branch.0.bn.running_mean
# features3.0.conv1x1_branch.0.bn.running_var
# features3.0.conv3x3_branch.0.conv.weight
# features3.0.conv3x3_branch.0.bn.weight
# features3.0.conv3x3_branch.0.bn.bias
# features3.0.conv3x3_branch.0.bn.running_mean
# features3.0.conv3x3_branch.0.bn.running_var
# features3.0.conv3x3_branch.1.conv.weight
# features3.0.conv3x3_branch.1.bn.weight
# features3.0.conv3x3_branch.1.bn.bias
# features3.0.conv3x3_branch.1.bn.running_mean
# features3.0.conv3x3_branch.1.bn.running_var
# features3.0.conv5x5_branch.0.conv.weight
# features3.0.conv5x5_branch.0.bn.weight
# features3.0.conv5x5_branch.0.bn.bias
# features3.0.conv5x5_branch.0.bn.running_mean
# features3.0.conv5x5_branch.0.bn.running_var
# features3.0.conv5x5_branch.1.conv.weight
# features3.0.conv5x5_branch.1.bn.weight
# features3.0.conv5x5_branch.1.bn.bias
# features3.0.conv5x5_branch.1.bn.running_mean
# features3.0.conv5x5_branch.1.bn.running_var
# features3.0.pool_branch.1.conv.weight
# features3.0.pool_branch.1.bn.weight
# features3.0.pool_branch.1.bn.bias
# features3.0.pool_branch.1.bn.running_mean
# features3.0.pool_branch.1.bn.running_var
# features3.2.conv1x1_branch.0.conv.weight
# features3.2.conv1x1_branch.0.bn.weight
# features3.2.conv1x1_branch.0.bn.bias
# features3.2.conv1x1_branch.0.bn.running_mean
# features3.2.conv1x1_branch.0.bn.running_var
# features3.2.conv3x3_branch.0.conv.weight
# features3.2.conv3x3_branch.0.bn.weight
# features3.2.conv3x3_branch.0.bn.bias
# features3.2.conv3x3_branch.0.bn.running_mean
# features3.2.conv3x3_branch.0.bn.running_var
# features3.2.conv3x3_branch.1.conv.weight
# features3.2.conv3x3_branch.1.bn.weight
# features3.2.conv3x3_branch.1.bn.bias
# features3.2.conv3x3_branch.1.bn.running_mean
# features3.2.conv3x3_branch.1.bn.running_var
# features3.2.conv5x5_branch.0.conv.weight
# features3.2.conv5x5_branch.0.bn.weight
# features3.2.conv5x5_branch.0.bn.bias
# features3.2.conv5x5_branch.0.bn.running_mean
# features3.2.conv5x5_branch.0.bn.running_var
# features3.2.conv5x5_branch.1.conv.weight
# features3.2.conv5x5_branch.1.bn.weight
# features3.2.conv5x5_branch.1.bn.bias
# features3.2.conv5x5_branch.1.bn.running_mean
# features3.2.conv5x5_branch.1.bn.running_var
# features3.2.pool_branch.1.conv.weight
# features3.2.pool_branch.1.bn.weight
# features3.2.pool_branch.1.bn.bias
# features3.2.pool_branch.1.bn.running_mean
# features3.2.pool_branch.1.bn.running_var
# features3.3.conv1x1_branch.0.conv.weight
# features3.3.conv1x1_branch.0.bn.weight
# features3.3.conv1x1_branch.0.bn.bias
# features3.3.conv1x1_branch.0.bn.running_mean
# features3.3.conv1x1_branch.0.bn.running_var
# features3.3.conv3x3_branch.0.conv.weight
# features3.3.conv3x3_branch.0.bn.weight
# features3.3.conv3x3_branch.0.bn.bias
# features3.3.conv3x3_branch.0.bn.running_mean
# features3.3.conv3x3_branch.0.bn.running_var
# features3.3.conv3x3_branch.1.conv.weight
# features3.3.conv3x3_branch.1.bn.weight
# features3.3.conv3x3_branch.1.bn.bias
# features3.3.conv3x3_branch.1.bn.running_mean
# features3.3.conv3x3_branch.1.bn.running_var
# features3.3.conv5x5_branch.0.conv.weight
# features3.3.conv5x5_branch.0.bn.weight
# features3.3.conv5x5_branch.0.bn.bias
# features3.3.conv5x5_branch.0.bn.running_mean
# features3.3.conv5x5_branch.0.bn.running_var
# features3.3.conv5x5_branch.1.conv.weight
# features3.3.conv5x5_branch.1.bn.weight
# features3.3.conv5x5_branch.1.bn.bias
# features3.3.conv5x5_branch.1.bn.running_mean
# features3.3.conv5x5_branch.1.bn.running_var
# features3.3.pool_branch.1.conv.weight
# features3.3.pool_branch.1.bn.weight
# features3.3.pool_branch.1.bn.bias
# features3.3.pool_branch.1.bn.running_mean
# features3.3.pool_branch.1.bn.running_var
# Aux1.aux_classifier.1.conv.weight
# Aux1.aux_classifier.1.bn.weight
# Aux1.aux_classifier.1.bn.bias
# Aux1.aux_classifier.1.bn.running_mean
# Aux1.aux_classifier.1.bn.running_var
# Aux1.classifier.0.weight
# Aux1.classifier.0.bias
# Aux1.classifier.2.weight
# Aux1.classifier.2.bias
# Aux2.aux_classifier.1.conv.weight
# Aux2.aux_classifier.1.bn.weight
# Aux2.aux_classifier.1.bn.bias
# Aux2.aux_classifier.1.bn.running_mean
# Aux2.aux_classifier.1.bn.running_var
# Aux2.classifier.0.weight
# Aux2.classifier.0.bias
# Aux2.classifier.2.weight
# Aux2.classifier.2.bias
# fc.weight
# fc.bias

# %%
params[0][1]
# Out:
# Variable containing:
# (0 ,.,.) =
# 1.00000e-02 *
#   -8.3639 -6.8963  5.0440  1.6571 -6.0828 -5.0083 -7.9698
#   -8.4651  0.0109 -2.3543 -7.0746  4.9806  5.1598 -1.8584
#   -0.6382 -2.2606  1.4104 -6.4806 -1.6392  4.9203 -3.5446
#    2.0459 -0.2692 -3.0612  4.0141 -0.9626 -4.7924  3.0227
#   -1.1420 -0.5830 -2.8491  4.6188 -7.3635 -3.1159  7.9916
#    3.8289  7.5868  3.3698 -5.0133  5.8351  9.4384  4.0263
#    6.6533  9.6733  3.2520  4.4351  6.8465 -0.7897  1.1419
#
# (1 ,.,.) =
# 1.00000e-02 *
#    1.1955  0.4231 -0.8941  1.0049  2.7524  3.0165 -5.2661
#   -7.1748  1.0516 -3.2741  5.0122 -3.9779  5.1753  1.8007
#   -6.4735  2.0323  5.9323 -7.8229  3.7652 -4.3847  0.5800
#    0.9324  5.8498  4.9334 -1.5156  0.8620 -1.9782  5.3362
#    5.1149  6.2336 -8.0849  1.9879  4.2239  3.1289  6.9130
#    0.1771  1.6349 -6.8430 -6.8321 -6.4354 -1.6176  0.8168
#    8.6020 -0.9828 -4.8187 -5.0227  3.6283  9.8376  8.4312
#
# (2 ,.,.) =
# 1.00000e-02 *
#    1.2600  6.5830 -3.9155 -4.9767 -4.6747 -1.0574 -8.6803
#    5.9453 -8.3011 -8.3641  4.1080 -5.0276 -8.1504 -6.0972
#   -6.4433  3.0221  4.3878  5.7542 -7.4870 -1.2295  0.9784
#   -3.3921 -3.0222 -5.3397 -4.0445 -8.2227 -7.9044  3.8258
#   -3.0817  5.9414 -3.8494  5.5730 -5.2198 -2.3156  7.6963
#    9.2271  7.5787 -3.1909 -5.1300  8.9938 -5.2387  1.8111
#    2.1640  6.7838  6.3873  0.8164  1.7063  6.0774 -4.6728
# [torch.cuda.FloatTensor of size 3x7x7 (GPU 0)]

# %%
test_model = nn.Sequential(*list(best_model.children())[:-3])

#  -1.4230 -1.5153 -1.5153  ...  -1.5306 -1.4845 -1.3922
#  -1.4691 -1.4845 -1.4384  ...  -1.5306 -1.4230 -1.3769
# [torch.FloatTensor of size 7x3x224x224]

# %%
pic_in, label = Variable(pic_in.cuda()),Variable(label.cuda())

# %%
for par in test_model.parameters():
    par.requires_grad=False

# %%
output = test_model(pic_in)

# %%
output.data.shape
# Out:
# torch.Size([7, 1024, 7, 7])

# %%
print(output.data)
# Out:
# ( 0  , 0  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 0  , 1  ,.,.) =
#   0.5254  0.4475  0.3383  ...   0.2192  0.2462  0.2051
#   0.6696  0.6957  0.6154  ...   0.4028  0.4578  0.3454
#   0.7117  0.8045  0.8256  ...   0.6657  0.6899  0.5117
#            ...             ⋱             ...
#   0.7649  0.8740  1.0302  ...   1.0490  1.0503  0.7741
#   0.8253  0.9343  1.0842  ...   1.0807  1.0608  0.7908
#   0.8288  0.9542  1.0745  ...   1.0972  1.0428  0.7494
#
# ( 0  , 2  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#       ...
#
# ( 0  ,1021,.,.) =
#   0.4048  0.3527  0.3103  ...   0.3198  0.3076  0.3261
#   0.3613  0.3154  0.2777  ...   0.2978  0.2689  0.2874
#   0.3536  0.3085  0.2790  ...   0.2957  0.2411  0.2576
#            ...             ⋱             ...
#   0.3627  0.3219  0.3145  ...   0.3386  0.2517  0.2460
#   0.3538  0.3130  0.3117  ...   0.3003  0.2288  0.2204
#   0.3481  0.3107  0.3093  ...   0.2995  0.2306  0.2308
#
# ( 0  ,1022,.,.) =
#   0.7534  0.8106  0.8636  ...   0.6749  0.6296  0.6861
#   0.7566  0.8850  0.9494  ...   0.7688  0.7284  0.8755
#   0.8225  0.9630  1.0615  ...   0.9476  0.8797  1.0629
#            ...             ⋱             ...
#   0.8618  1.0261  1.1563  ...   1.1597  1.0859  1.2170
#   0.8570  1.0019  1.1040  ...   1.1150  1.0436  1.1435
#   0.8623  0.9943  1.0901  ...   1.1150  1.0455  1.1228
#
# ( 0  ,1023,.,.) =
#   0.1113  0.1081  0.1001  ...   0.1727  0.1465  0.1293
#   0.1081  0.0974  0.0908  ...   0.1721  0.1289  0.0917
#   0.0960  0.0811  0.0690  ...   0.1113  0.0710  0.0277
#            ...             ⋱             ...
#   0.0875  0.0592  0.0289  ...   0.0304  0.0000  0.0000
#   0.0646  0.0370  0.0146  ...   0.0000  0.0000  0.0000
#   0.0533  0.0289  0.0080  ...   0.0000  0.0000  0.0000
#         ⋮
#
# ( 1  , 0  ,.,.) =
#   0.0596  0.1233  0.1302  ...   0.1336  0.1329  0.1136
#   0.1143  0.1667  0.1651  ...   0.1730  0.1844  0.1654
#   0.1137  0.1299  0.0886  ...   0.0855  0.1515  0.1593
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0087  0.0039  0.0000
#   0.0000  0.0000  0.0000  ...   0.0211  0.0118  0.0000
#
# ( 1  , 1  ,.,.) =
#   0.0000  0.0000  0.0094  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0
0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.6106  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 4  , 2  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0414  ...   0.0335  0.0056  0.0000
#            ...             ⋱             ...
#   0.0269  0.0302  0.0369  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#       ...
#
# ( 4  ,1021,.,.) =
#   0.3351  0.2336  0.1474  ...   0.1150  0.1112  0.2000
#   0.1030  0.0206  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 4  ,1022,.,.) =
#   0.7819  0.8423  0.8303  ...   0.6401  0.5949  0.5740
#   0.9819  1.0111  0.7583  ...   0.2648  0.0861  0.0000
#   0.8849  0.7908  0.4485  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.3685  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.5894  0.3341  0.0101  ...   0.0000  0.0000  0.0000
#   0.4815  0.3634  0.1410  ...   0.0000  0.0000  0.0000
#
# ( 4  ,1023,.,.) =
#   0.1060  0.0911  0.0943  ...   0.1628  0.1256  0.1362
#   0.0025  0.0000  0.0000  ...   0.0800  0.0819  0.1110
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0706
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0029  0.2001
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.1722
#   0.0000  0.0000  0.0000  ...   0.0000  0.1434  0.3071
#         ⋮
#
# ( 5  , 0  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0100  0.0207  0.0113
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0066  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 5  , 1  ,.,.) =
#   0.3322  0.0474  0.0000  ...   0.0000  0.0000  0.0000
#   0.3999  0.0746  0.0000  ...   0.0000  0.0000  0.0000
#   0.4957  0.3704  0.3226  ...   0.4429  0.1694  0.0000
#            ...             ⋱             ...
#   0.6719  0.7827  0.9540  ...   0.8970  0.6815  0.4444
#   0.7579  0.8853  1.0444  ...   0.9688  0.8878  0.6081
#   0.7699  0.9100  1.0435  ...   0.9988  0.9733  0.6896
#
# ( 5  , 2  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#       ...
#
# ( 5  ,1021,.,.) =
#   0.3790  0.2875  0.1715  ...   0.0342  0.0226  0.0909
#   0.3649  0.2460  0.1283  ...   0.0000  0.0000  0.0000
#   0.3740  0.2738  0.1733  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.4046  0.3613  0.3402  ...   0.0000  0.0000  0.0000
#   0.3698  0.3271  0.3141  ...   0.1477  0.0977  0.1067
#   0.3615  0.3223  0.3133  ...   0.2868  0.2328  0.2419
#
# ( 5  ,1022,.,.) =
#   0.4923  0.4215  0.3660  ...   0.1862  0.0524  0.0267
#   0.5953  0.6297  0.6257  ...   0.4217  0.1900  0.0099
#   0.6690  0.7125  0.8012  ...   1.0064  0.8101  0.5812
#            ...             ⋱             ...
#   0.8059  1.0024  1.1256  ...   1.2387  1.1273  1.1002
#   0.7807  0.9592  1.0832  ...   1.2069  1.0557  1.0626
#   0.8097  0.9647  1.0830  ...   1.1430  1.0192  1.0112
#
# ( 5  ,1023,.,.) =
#   0.1930  0.2064  0.2285  ...   0.2334  0.2304  0.2458
#   0.1959  0.1972  0.2020  ...   0.1014  0.1041  0.1266
#   0.1806  0.1807  0.1671  ...   0.0000  0.0000  0.0277
#            ...             ⋱             ...
#   0.1391  0.1152  0.0912  ...   0.0000  0.0000  0.0000
#   0.1091  0.0839  0.0627  ...   0.0000  0.0000  0.0000
#   0.0915  0.0683  0.0467  ...   0.0378  0.0346  0.0304
#         ⋮
#
# ( 6  , 0  ,.,.) =
#   0.0585  0.1244  0.1330  ...   0.1379  0.1376  0.1182
#   0.1128  0.1673  0.1679  ...   0.1684  0.1750  0.1545
#   0.1116  0.1378  0.1133  ...   0.0805  0.1297  0.1226
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#
# ( 6  , 1  ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.4656  0.5069  0.5967  ...   0.4878  0.4362  0.2199
#   0.7631  0.8405  0.9255  ...   0.8536  0.8692  0.6001
#   0.7855  0.8908  1.0224  ...   1.0513  1.0153  0.7397
#
# ( 6  , 2  ,.,.) =
#   0.6536  1.4523  1.5230  ...   1.5566  1.5501  1.2942
#   1.3578  1.9963  1.9781  ...   1.9642  2.0263  1.6794
#   1.1936  1.5556  1.2927  ...   0.9075  1.4348  1.3076
#            ...             ⋱             ...
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#       ...
#
# ( 6  ,1021,.,.) =
#   0.6170  0.6125  0.6010  ...   0.6105  0.6076  0.6173
#   0.6146  0.5966  0.5595  ...   0.5699  0.5754  0.6077
#   0.6181  0.5023  0.4504  ...   0.4504  0.4986  0.5334
#            ...             ⋱             ...
#   0.3322  0.1801  0.1134  ...   0.1127  0.1233  0.1590
#   0.3271  0.2290  0.2059  ...   0.2237  0.1985  0.2112
#   0.3544  0.3137  0.3060  ...   0.3078  0.2461  0.2551
#
# ( 6  ,1022,.,.) =
#   0.1282  0.1431  0.1866  ...   0.1753  0.1618  0.2164
#   0.1387  0.1731  0.2170  ...   0.1725  0.1581  0.2016
#   0.2496  0.2635  0.2892  ...   0.1723  0.1379  0.1993
#            ...             ⋱             ...
#   0.8220  0.8920  0.9827  ...   0.8990  0.7702  0.8900
#   0.8850  0.9838  1.0331  ...   0.9942  0.8768  0.9639
#   0.8796  1.0073  1.0574  ...   1.0198  0.9197  0.9892
#
# ( 6  ,1023,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#            ...             ⋱             ...
#   0.0972  0.0644  0.0870  ...   0.0924  0.0693  0.0432
#   0.0905  0.0628  0.0676  ...   0.0622  0.0517  0.0299
#   0.0843  0.0694  0.0733  ...   0.0676  0.0513  0.0344
# [torch.cuda.FloatTensor of size 7x1024x7x7 (GPU 0)]

# %%
new_out = F.avg_pool2d(output, kernel_size=7)
b = new_out.view(-1 ,1024)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-9b064d399a78> in <module>()
#       2 b = new_out.view(-1 ,1024)
#       3 fc = nn.Linear(1024,3)
# ----> 4 f = fc(b)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     551     if input.dim() == 2 and bias is not None:
#     552         # fused op is marginally faster
# --> 553         return torch.addmm(bias, input, weight.t())
#     554
#     555     output = input.matmul(weight.t())
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/variable.py in addmm(cls, *args)
#     922         @classmethod
#     923         def addmm(cls, *args):
# --> 924             return cls._blas(Addmm, args, False)
#     925
#     926         @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/variable.py in _blas(cls, args, inplace)
#     918             else:
#     919                 tensors = args
# --> 920             return cls.apply(*(tensors + (alpha, beta, inplace)))
#     921
#     922         @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/_functions/blas.py in forward(ctx, add_matrix, matrix1, matrix2, alpha, beta, inplace)
#      24         output = _get_output(ctx, add_matrix, inplace=inplace)
#      25         return torch.addmm(alpha, add_matrix, beta,
# ---> 26                            matrix1, matrix2, out=output)
#      27
#      28     @staticmethod
#
# TypeError: torch.addmm received an invalid combination of arguments - got (int, torch.FloatTensor, int, torch.cuda.FloatTensor, torch.FloatTensor, out=torch.FloatTensor), but expected one of:
#  * (torch.FloatTensor source, torch.FloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (torch.FloatTensor source, torch.SparseFloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (float beta, torch.FloatTensor source, torch.FloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (torch.FloatTensor source, float alpha, torch.FloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (float beta, torch.FloatTensor source, torch.SparseFloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (torch.FloatTensor source, float alpha, torch.SparseFloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#  * (float beta, torch.FloatTensor source, float alpha, torch.FloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#       didn't match because some of the arguments have invalid types: (int, torch.FloatTensor, int, torch.cuda.FloatTensor, torch.FloatTensor, out=torch.FloatTensor)
#  * (float beta, torch.FloatTensor source, float alpha, torch.SparseFloatTensor mat1, torch.FloatTensor mat2, *, torch.FloatTensor out)
#       didn't match because some of the arguments have invalid types: (int, torch.FloatTensor, int, torch.cuda.FloatTensor, torch.FloatTensor, out=torch.FloatTensor)

# %%
print(b.data.shape)
# Out:
# torch.Size([7, 1024])

# %%
output_np = output.data.cpu().numpy()
new_out_np = new_out.data.cpu().numpy()

# %%
output_np.shape
new_out_np.shape
# Out:
# (7, 1024, 1, 1)

# %%
channel_0 = output_np[0,:]
print(channel_0.shape)
# Out:
# (1024, 7, 7)

# %%
new_re = channel_0.reshape((224,224))

# %%
plt.imshow(new_re)

# %%
channel_1 = output_np[1,:]
new_re_1 = channel_1.reshape((224,224))
plt.imshow(new_re_1)

# %%
print(test_model)
# Out:
# Sequential (
#   (0): Sequential (
#     (0): _Stem (
#       (stem): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#         (2): BasicConv2d (
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (3): BasicConv2d (
#           (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (4): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (4): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (1): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (2): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
# )

# %%
channel_2 = output_np[2,:]
new_re_2 = channel_2.reshape((224,224))
plt.imshow(new_re_2)

# %%
num_kernels = 1024
num_rows = 32
num_cols = 32
fig=plt.figure(figsize=(num_cols,num_rows))
for i in range(1024):
    ax1 = fig.add_subplot(num_rows, num_cols, i+1)
    ax1.imshow(channel_2[i])
    ax1.axis('off')
    ax1.set_xticklabels([])
    ax1.set_yticklabels([])
plt.subplots_adjust(wspace=0.1,hspace=0.1)
plt.show()

# %%
fig.savefig('filter_img.png')

# %%
out_2 = new_out_np[2,:]
new_re_2 = out_2.reshape((32,32))
plt.imshow(new_re_2)

# %%
test_model_2 = nn.Sequential(*list(best_model.children())[:-1])
for par in test_model_2.parameters():
    par.requires_grad=False

# %%
print(test_model_2)
# Out:
# Sequential (
#   (0): Sequential (
#     (0): _Stem (
#       (stem): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#         (2): BasicConv2d (
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#         (3): BasicConv2d (
#           (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (4): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (4): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (1): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (2): Sequential (
#     (0): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (1): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#     (2): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#     (3): _Inception_Module (
#       (conv1x1_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv3x3_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (conv5x5_branch): Sequential (
#         (0): BasicConv2d (
#           (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True)
#         )
#         (1): BasicConv2d (
#           (conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#       (pool_branch): Sequential (
#         (0): MaxPool2d (size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(1, 1))
#         (1): BasicConv2d (
#           (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#         )
#       )
#     )
#   )
#   (3): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
#   (4): _Auxiliary_Classifiers (
#     (aux_classifier): Sequential (
#       (0): AvgPool2d (size=5, stride=3, padding=2, ceil_mode=False, count_include_pad=True)
#       (1): BasicConv2d (
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True)
#       )
#     )
#     (classifier): Sequential (
#       (0): Linear (3200 -> 1024)
#       (1): Dropout (p = 0.7)
#       (2): Linear (1024 -> 3)
#     )
#   )
# )

# %%
pic_in, label = next(iter(dset_loaders['train']))

# %%
pic_in, label = Variable(pic_in.cuda()),Variable(label.cuda())

# %%
feature_blobs = []
def hook_feature(module, input, output):
    feature_blobs.append(output.data.cpu().numpy())

# %%
best_model._modules.get('features3').register_forward_hook(hook_feature)

# %%
params = list(best_model.parameters())

# %%
weight_softmax = np.squeeze(params[-2].data.cpu().numpy())
print(weight_softmax)
print(weight_softmax.shape)
weight_softmax[0]
# Out:
# [[ 0.00875173  0.01881819  0.02255012 ..., -0.01047539 -0.02570237
#    0.0288222 ]
#  [-0.01518493 -0.01523327 -0.04039299 ..., -0.00985893 -0.01732344
#   -0.02366675]
#  [-0.00519276  0.04460569 -0.01286171 ..., -0.02601173  0.04244735
#   -0.00380298]]
# (3, 1024)
# array([ 0.00875173,  0.01881819,  0.02255012, ..., -0.01047539,
#        -0.02570237,  0.0288222 ], dtype=float32)

# %%
def returnCAM(feature_conv, weight_softmax, class_idx):
    #generate the class activation maps upsample to 256*256
    size_upsample = (256,256)
    bz,nc,h,w = feature_conv.shape
    print(bz)
    print(nc)
    print(h)
    print(w)
    output_cam = []
    for num,idx in enumerate(class_idx):
        
        cam = weight_softmax[idx].dot(feature_conv[num].reshape((nc, h*w)))
        cam = cam.reshape(h,w)
        cam = cam - np.min(cam)
        cam_img = cam/np.max(cam)
        cam_img = np.uint8(255*cam_img)
        output_cam.append(cv2.resize(cam_img, size_upsample))
    return output_cam

# %%
logit = best_model(pic_in)

# %%
print(logit)
# Out:
# Variable containing:
# -2.9247 -3.3262  5.4453
# -3.4840 -3.4566  6.0637
#  3.3931 -2.7130 -1.9115
# -3.2177 -3.3654  5.7401
# -3.6035 -3.3150  6.0527
# -1.7228  1.8691 -1.2119
# -3.3081 -2.3795  4.9271
# [torch.cuda.FloatTensor of size 7x3 (GPU 0)]

# %%
h_x = F.softmax(logit).data.cpu().squeeze()

# %%
probs, idx = h_x.sort(1, True)

# %%
print(idx)
idx_np = idx.numpy()
print(idx_np)
idx_array = idx_np[:,0]
idx_array = [int(i) for i in idx_array]
print(idx_array)
# Out:
#     2     0     1
#     2     1     0
#     0     2     1
#     2     0     1
#     2     1     0
#     1     2     0
#     2     1     0
# [torch.LongTensor of size 7x3]
#
# [[2 0 1]
#  [2 1 0]
#  [0 2 1]
#  [2 0 1]
#  [2 1 0]
#  [1 2 0]
#  [2 1 0]]
# [2, 2, 0, 2, 2, 1, 2]

# %%
print(feature_blobs)
# Out:
# [array([[[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [  1.25260968e-02,   1.12436144e-02,   9.95267183e-03, ...,
#             9.93567985e-03,   9.28928982e-03,   9.53735877e-03],
#          [  1.59355737e-02,   1.45283053e-02,   1.36146387e-02, ...,
#             1.32995695e-02,   1.27648897e-02,   1.18494872e-02],
#          [  1.47138899e-02,   1.38826901e-02,   1.31425187e-02, ...,
#             1.31811658e-02,   1.30041121e-02,   1.22805284e-02]],
#
#         [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [  1.61525473e-01,   1.24994203e-01,   9.40568447e-02, ...,
#             1.02460466e-01,   8.36894065e-02,   8.62740129e-02],
#          [  2.50537336e-01,   2.21778676e-01,   2.06846938e-01, ...,
#             2.10580558e-01,   1.96749881e-01,   1.79175258e-01],
#          [  2.32661426e-01,   2.26279825e-01,   2.20489621e-01, ...,
#             2.18723729e-01,   2.14305758e-01,   2.00755253e-01]],
#
#         [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   6.95949867e-02, ...,
#             2.27866396e-01,   2.82987882e-03,   0.00000000e+00],
#          ...,
#          [  0.00000000e+00,   3.44955176e-03,   1.71829864e-01, ...,
#             1.55013293e-01,   3.25357206e-02,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00]],
#
#         ...,
#         [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00]],
#
#         [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [  1.03068568e-01,   2.86777839e-02,   5.61913475e-03, ...,
#             4.00731862e-02,   3.36751081e-02,   1.06792077e-01],
#          [  2.39754662e-01,   1.94812626e-01,   1.94573402e-01, ...,
#             2.03782618e-01,   2.14145944e-01,   2.54981369e-01],
#          [  3.01083565e-01,   2.90628999e-01,   2.93861270e-01, ...,
#             3.01132500e-01,   3.04459542e-01,   3.16573739e-01]],
#
#         [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00]]],
#
#
#        [[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          ...,
#          [
  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#          [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,   0.00000000e+00]]]], dtype=float32)]

# %%
print(len(feature_blobs[0]))
#print(feature_blobs[0])
print(len(feature_blobs[0][0]))
# Out:
# 7
# 1024

# %%
CAMs = returnCAM(feature_blobs[0],weight_softmax,idx_array)
# Out:
# 7
# 1024
# 7
# 7

# %%
test_pic = pic_in.data.cpu().numpy()

# %%
print(test_pic.shape)
print(test_pic[0].shape)
# Out:
# (7, 3, 224, 224)
# (3, 224, 224)

# %%
print(CAMs)
print(len(CAMs[0]))
# Out:
# [array([[128, 128, 128, ..., 125, 125, 125],
#        [128, 128, 128, ..., 125, 125, 125],
#        [128, 128, 128, ..., 125, 125, 125],
#        ...,
#        [ 33,  33,  33, ...,  32,  32,  32],
#        [ 33,  33,  33, ...,  32,  32,  32],
#        [ 33,  33,  33, ...,  32,  32,  32]], dtype=uint8), array([[122, 122, 122, ..., 121, 121, 121],
#        [122, 122, 122, ..., 121, 121, 121],
#        [122, 122, 122, ..., 121, 121, 121],
#        ...,
#        [ 28,  28,  28, ...,  27,  27,  27],
#        [ 28,  28,  28, ...,  27,  27,  27],
#        [ 28,  28,  28, ...,  27,  27,  27]], dtype=uint8), array([[ 0,  0,  0, ...,  7,  7,  7],
#        [ 0,  0,  0, ...,  7,  7,  7],
#        [ 0,  0,  0, ...,  7,  7,  7],
#        ...,
#        [34, 34, 34, ..., 10, 10, 10],
#        [34, 34, 34, ..., 10, 10, 10],
#        [34, 34, 34, ..., 10, 10, 10]], dtype=uint8), array([[126, 126, 126, ..., 130, 130, 130],
#        [126, 126, 126, ..., 130, 130, 130],
#        [126, 126, 126, ..., 130, 130, 130],
#        ...,
#        [ 33,  33,  33, ...,  32,  32,  32],
#        [ 33,  33,  33, ...,  32,  32,  32],
#        [ 33,  33,  33, ...,  32,  32,  32]], dtype=uint8), array([[123, 123, 123, ..., 123, 123, 123],
#        [123, 123, 123, ..., 123, 123, 123],
#        [123, 123, 123, ..., 123, 123, 123],
#        ...,
#        [ 31,  31,  31, ...,  30,  30,  30],
#        [ 31,  31,  31, ...,  30,  30,  30],
#        [ 31,  31,  31, ...,  30,  30,  30]], dtype=uint8), array([[ 0,  0,  0, ...,  8,  8,  8],
#        [ 0,  0,  0, ...,  8,  8,  8],
#        [ 0,  0,  0, ...,  8,  8,  8],
#        ...,
#        [88, 88, 88, ..., 94, 94, 94],
#        [88, 88, 88, ..., 94, 94, 94],
#        [88, 88, 88, ..., 94, 94, 94]], dtype=uint8), array([[130, 130, 130, ..., 113, 113, 113],
#        [130, 130, 130, ..., 113, 113, 113],
#        [130, 130, 130, ..., 113, 113, 113],
#        ...,
#        [ 41,  41,  41, ...,   0,   0,   0],
#        [ 41,  41,  41, ...,   0,   0,   0],
#        [ 41,  41,  41, ...,   0,   0,   0]], dtype=uint8)]
# 256

# %%
test_img = cv2.imread('./alzheimers/label_0/OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc_cor_110.jpg')
test_img_1 = cv2.resize(test_img,(224,224))
print(test_img_1.shape)
cv2.imwrite('test_1.jpg',test_img_1)
# Out:
# (224, 224, 3)
# True

# %%
height,width,_ = test_img_1.shape

# %%
heatmap = cv2.applyColorMap(cv2.resize(CAMs[0],(width,height)), cv2.COLORMAP_JET)

# %%
result = heatmap*0.3 + test_img_1*0.5

# %%
cv2.imwrite('CAM.jpg',result)
# Out:
# True
